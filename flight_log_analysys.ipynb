# %%
import numpy as np
import matplotlib.pyplot as plt

data=np.loadtxt('ekflog21.txt')#, delimiter=',', skiprows=1)

t=data.T[0]
q0=data.T[1]
q1=data.T[2]
q2=data.T[3]
q3=data.T[4]
dp=data.T[5]
dq=data.T[6]
dr=data.T[7]
Wp=data.T[8]
Wq=data.T[9]
Wr=data.T[10]
Ax=data.T[11]
Ay=data.T[12]
Az=data.T[13]
Mx=data.T[14]
My=data.T[15]
Mz=data.T[16]

p_ref=data.T[17]
q_ref=data.T[18]
r_ref=data.T[19]

phi=data.T[20]
theta=data.T[21]
psi=data.T[22]

phi_ref=data.T[23]
theta_ref=data.T[24]
psi_ref=data.T[25]

Pcom=data.T[26]
Qcom=data.T[27]
Rcom=data.T[28]

pd=data.T[29]
qd=data.T[30]
rd=data.T[31]

phid=data.T[32]
thetad=data.T[33]

# %%
tmin=0
tmax=14
ax1=plt.figure(figsize=(16,9))

ax1.add_subplot(321)
plt.plot(t,Wp,label='p')
plt.plot(t,p_ref,label='p_ref')
plt.legend()
plt.ylabel('Roll rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.5,1.5])
plt.grid()

ax1.add_subplot(323)
plt.plot(t,Wq,label='q')
plt.plot(t,q_ref,label='q_ref')
plt.legend()
plt.ylabel('Pitch rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1,1])
plt.grid()

ax1.add_subplot(325)
plt.plot(t,Wr,label='r')
plt.plot(t,r_ref,label='r_ref')
plt.legend()
plt.ylabel('Yaw rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-0.5,0.5])
plt.grid()

ax1.add_subplot(322)
plt.plot(t,phi,label='phi')
plt.plot(t,phi_ref,label='phi_ref')
plt.legend()
plt.ylabel('Roll angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.2,0.2])
plt.grid()

ax1.add_subplot(324)
plt.plot(t,theta,label='theta')
plt.plot(t,theta_ref,label='theta_ref')
plt.legend()
plt.ylabel('Pitch angle[rad]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()

ax1.add_subplot(326)
plt.plot(t,psi,label='psi')
plt.legend()
plt.ylabel('Yaw angle[rad]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()
plt.show()




ax2=plt.figure(figsize=(16,5))
ax2.add_subplot(321)
plt.plot(t,Pcom,label='Pcom')
plt.legend()
plt.ylabel('Pcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(323)
plt.plot(t,Qcom,label='Qcom')
plt.legend()
plt.ylabel('Qcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(325)
plt.plot(t,Rcom,label='Rcom')
plt.legend()
plt.ylabel('Rcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

plt.show()


ax3=plt.figure(figsize=(16,8))
ax3.add_subplot(321)
plt.plot(t,pd,label='pd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(323)
plt.plot(t,qd,label='qd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(325)
plt.plot(t,rd,label='rd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(322)
plt.plot(t,phid,label='phid')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(324)
plt.plot(t,thetad,label='thetad')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()



plt.show()

# %%
tmin=0
tmax=10
ax1=plt.figure(figsize=(16,9))

ax1.add_subplot(321)
plt.plot(t,Wp,label='p')
plt.plot(t,p_ref,label='p_ref')
plt.legend()
plt.ylabel('Roll rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.5,1.5])
plt.grid()

ax1.add_subplot(323)
plt.plot(t,Wq,label='q')
plt.plot(t,q_ref,label='q_ref')
plt.legend()
plt.ylabel('Pitch rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1,1])
plt.grid()

ax1.add_subplot(325)
plt.plot(t,Wr,label='r')
plt.plot(t,r_ref,label='r_ref')
plt.legend()
plt.ylabel('Yaw rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-0.5,0.5])
plt.grid()

ax1.add_subplot(322)
plt.plot(t,phi_ref-phi,label='phi_err')
#plt.plot(t,phi_ref,label='phi_ref')
plt.legend()
plt.ylabel('Roll error angle[rad]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()

ax1.add_subplot(324)
plt.plot(t,theta_ref-theta,label='theta_err')
#plt.plot(t,theta_ref,label='theta_ref')
plt.legend()
plt.ylabel('Pitch error angle[rad]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()
plt.show()

ax2=plt.figure(figsize=(16,5))
ax2.add_subplot(321)
plt.plot(t,Pcom,label='Pcom')
plt.legend()
plt.ylabel('Pcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(323)
plt.plot(t,Qcom,label='Qcom')
plt.legend()
plt.ylabel('Qcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(325)
plt.plot(t,Rcom,label='Rcom')
plt.legend()
plt.ylabel('Rcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

plt.show()


ax3=plt.figure(figsize=(16,8))
ax3.add_subplot(321)
plt.plot(t,pd,label='pd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(323)
plt.plot(t,qd,label='qd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(325)
plt.plot(t,rd,label='rd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(322)
plt.plot(t,phid,label='phid')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(324)
plt.plot(t,thetad,label='thetad')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()



plt.show()

# %%
tmin=0
tmax=max(t)
ax1=plt.figure(figsize=(16,16))
ax1.add_subplot(611)
plt.plot(t,q0,label='q0')
plt.plot(t,q1,label='q1')
plt.plot(t,q2,label='q2')
plt.plot(t,q3,label='q3')
plt.legend(loc='upper right')
#plt.xlim([0,max(t)])
plt.ylabel('Quaternion')
plt.xlim([tmin,tmax])

plt.grid()
#plt.show()

e11=q0**2+q1**2-q2**2-q3**2
e12=2*(q1*q2+q0*q3)
e13=2*(q1*q3-q0*q2)
e23=2*(q2*q3+q0*q1)
e33=q0**2-q1**2-q2**2+q3**2
phi=np.arctan2(e23,e33)
theta=np.arctan2(-e13,np.sqrt(e23**2+e33**2))
psi=np.arctan2(e12,e11)

ax1.add_subplot(612)
#plt.figure(figsize=(16,4))
plt.plot(t,phi*180/np.pi,label='phi')
plt.plot(t,theta*180/np.pi,label='theta')
plt.plot(t,psi*180/np.pi,label='psi')
plt.legend()
plt.ylabel('Angle[deg]')
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-50,50])
plt.grid()



ax1.add_subplot(613)
#plt.figure(figsize=(16,4))
plt.plot(t,Wp*180/np.pi,label='p')
plt.plot(t,Wq*180/np.pi,label='q')
plt.plot(t,Wr*180/np.pi,label='r')

plt.plot(t,dp*180/np.pi,label='dp')
plt.plot(t,dq*180/np.pi,label='dq')
plt.plot(t,dr*180/np.pi,label='dr')
plt.legend()
plt.ylabel('Angle rate[deg/s]')
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
plt.ylim([-1,5])
plt.grid()

ax1.add_subplot(614)
#plt.figure(figsize=(16,4))
plt.plot(t,Wp*180/np.pi,label='p')
plt.plot(t,Wq*180/np.pi,label='q')
plt.plot(t,Wr*180/np.pi,label='r')
plt.legend()
plt.ylabel('Angle rate[deg/s]')
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-90,90])
plt.grid()


ax1.add_subplot(615)
#plt.figure(figsize=(16,4))
plt.plot(t,Ax,label='ax')
plt.plot(t,Ay,label='ay')
plt.plot(t,Az,label='az')
plt.legend()
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-50,50])
plt.ylabel('Acceleration[m/s^2]')
plt.grid()
plt.xlabel('Time[s]')

ax1.add_subplot(616)
#plt.figure(figsize=(16,4))
plt.plot(t,Mx,label='mx')
plt.plot(t,My,label='my')
plt.plot(t,Mz,label='mz')
#plt.plot(t,MN,label='MN')
#plt.plot(t,ME,label='ME')
#plt.plot(t,MD,label='MD')

plt.legend()
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-50,50])
plt.ylabel('Mag')
plt.grid()
plt.xlabel('Time[s]')

plt.show()

# %%
h=0.0025
T=0.0075
err=p_ref-Wp
derr=(err[1:]-err[0:-1])/h


Y=[]
y=0
for x in derr:    
    y=y*T/(T+h)+x*h/(T+h)
    Y.append(y)
Y=np.array(Y)
#plt.figure(figsize=(16,9))
plt.plot(t[0:-1], derr)
plt.plot(t[0:-1], Y)
plt.plot(t,pd)
#plt.ylim(-50,50)
plt.xlim(5,8)
plt.grid()

# %%
h=0.01
T=0.01*3

err=phi_ref-phi
derr=(err[1:]-err[0:-1])/h

Y=[]
y=0
for x in derr:
    y=y*T/(T+h)+x*h/(T+h)
    Y.append(y)
Y=np.array(Y)
#plt.figure(figsize=(16,9))
plt.plot(t[0:-1], derr)
plt.plot(t[0:-1], Y)

#plt.ylim(-1,1)
plt.xlim(0,10)
plt.grid()

# %%
tmin=0
tmax=14
ax1=plt.figure(figsize=(16,9))

ax1.add_subplot(321)
plt.plot(t,Mx,label='mx')
plt.legend()
plt.ylabel('Mag x')
plt.xlim([tmin,tmax])
#plt.ylim([-1.5,1.5])
plt.grid()

ax1.add_subplot(323)
plt.plot(t,My,label='my')
plt.legend()
plt.ylabel('Mag y')
plt.xlim([tmin,tmax])
plt.ylim([-0.1,0.9])
plt.grid()

ax1.add_subplot(325)
plt.plot(t,Mz,label='mz')
plt.legend()
plt.ylabel('Mag z')
plt.xlim([tmin,tmax])
plt.ylim([0.85,1.0])
plt.grid()

ax1.add_subplot(322)
plt.plot(t,phi*180/np.pi,label='phi')
plt.plot(t,phi_ref*180/np.pi,label='phi_ref')
plt.legend()
plt.ylabel('Roll angle[deg]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()

ax1.add_subplot(324)
plt.plot(t,theta*180/np.pi,label='theta')
plt.plot(t,theta_ref*180/np.pi,label='theta_ref')
plt.legend()
plt.ylabel('Pitch angle[deg]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()

ax1.add_subplot(326)
plt.plot(t,psi*180/np.pi,label='psi')
plt.legend()
plt.ylabel('Yaw angle[deg]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()
plt.show()

# %%
print(Mx[200:500].var())
print(My[200:500].var())
print(Mz[200:500].var())
# Out:
# 6.171399363888887e-05
# 7.463564947888889e-05
# 0.00010539084457333329

# %%
print(Ax[200:500].var())
print(Ay[200:500].var())
print(Az[200:500].var())
# Out:
# 0.00012697607264333343
# 0.00011017864552333329
# 8.223666574555553e-05

# %%
fr=(-Pcom +Qcom +Rcom)*0.25
fl=( Pcom +Qcom -Rcom)*0.25
rr=(-Pcom -Qcom -Rcom)*0.25
rl=( Pcom -Qcom +Rcom)*0.25

plt.plot(t,fr,label='fr')
plt.legend()
plt.grid()
plt.show()
plt.plot(t,fl,label='fl')
plt.legend()
plt.grid()
plt.show()
plt.plot(t,rr,label='rr')
plt.legend()
plt.grid()
plt.show()
plt.plot(t,rl,label='rl')
plt.legend()
plt.grid()
plt.show()

# %%
phi_ref
# Out:
# array([-0.08, -0.08, -0.08, ..., -0.08, -0.08, -0.08])

# %%
theta_ref
# Out:
# array([-0.01   , -0.01   , -0.01   , ...,  0.10534,  0.10534,  0.0592 ])

# %%
psi_ref
# Out:
# array([ 0.00262,  0.00262,  0.00262, ..., -0.01415, -0.01415, -0.01415])
